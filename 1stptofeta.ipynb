# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
heart= pd.read_csv('selected_heartdata.csv')

# %%
heart.head()
# Out:
#    HeartDisease  GenHealth  DiffWalking  Stroke  PhysicalHealth
# 0             0          3            0       0             3.0
# 1             0          3            0       1             0.0
# 2             0          2            0       0             0.0
# 3             0          1            0       0             0.0
# 4             0          2            1       0             0.0

# %%
print(heart.dtypes)
PhysicalHealth = pd.DataFrame(heart['PhysicalHealth'])
# Out:
# HeartDisease        int64
# GenHealth           int64
# DiffWalking         int64
# Stroke              int64
# PhysicalHealth    float64
# dtype: object

# %%
PhysicalHealth = pd.DataFrame(heart['PhysicalHealth'])
GenHealth = pd.DataFrame(heart['GenHealth'])
DiffWalking = pd.DataFrame(heart['DiffWalking'])
Stroke = pd.DataFrame(heart['Stroke'])
HeartDisease = pd.DataFrame(heart['HeartDisease'])

# %%
f = plt.figure(figsize=(16, 8))
sb.boxplot(data = PhysicalHealth, orient = "h")



f = plt.figure(figsize=(16, 8))
sb.boxplot(data = GenHealth, orient = "h")



f = plt.figure(figsize=(16, 8))
sb.boxplot(data = DiffWalking, orient = "h")


f = plt.figure(figsize=(16, 8))
sb.boxplot(data = Stroke, orient = "h")
# Out:
# <Axes: >

# %%
# Extract only the numeric data variables
numeric_data = pd.DataFrame(heart)

# Summary Statistics for all Variables
numeric_data.describe()
# Out:
#         HeartDisease      GenHealth    DiffWalking         Stroke  \
# count  265043.000000  265043.000000  265043.000000  265043.000000
# mean        0.066152       2.806658       0.079527       0.027033
# std         0.248547       0.893576       0.270560       0.162181
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       2.000000       0.000000       0.000000
# 50%         0.000000       3.000000       0.000000       0.000000
# 75%         0.000000       3.000000       0.000000       0.000000
# max         1.000000       4.000000       1.000000       1.000000
#
#        PhysicalHealth
# count   265043.000000
# mean         0.316824
# std          0.852112
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          4.000000

# %%
f = plt.figure(figsize=(16, 8))
sb.violinplot(data = PhysicalHealth, orient = "h")


f = plt.figure(figsize=(16, 8))
sb.violinplot(data = GenHealth, orient = "h")


f = plt.figure(figsize=(16, 8))
sb.violinplot(data = DiffWalking, orient = "h")


f = plt.figure(figsize=(16, 8))
sb.violinplot(data = Stroke, orient = "h")
# Out:
# <Axes: >

# %%
f = plt.figure(figsize=(16, 8))
sb.histplot(data = PhysicalHealth)



f = plt.figure(figsize=(16, 8))
sb.histplot(data = GenHealth)



f = plt.figure(figsize=(16, 8))
sb.histplot(data = DiffWalking)



f = plt.figure(figsize=(16, 8))
sb.histplot(data = Stroke)
# Out:
# <Axes: ylabel='Count'>

# %%
sb.catplot(x="PhysicalHealth", y="HeartDisease", data=heart)
plt.show()



sb.catplot(x="GenHealth", y="HeartDisease", data=heart)
plt.show()


sb.catplot(x="Stroke", y="HeartDisease", data=heart)
plt.show()


sb.catplot(x="DiffWalking", y="HeartDisease", data=heart)
plt.show()
# Out:
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig, axes = plt.subplots(1, 1, figsize=(15, 10))
sb.boxplot(data = cleaneddata, x = "GarageCars", y = "SalePrice")
sb.jointplot(data = cleaneddata, x = "GarageCars", y = "SalePrice", height = 12)
