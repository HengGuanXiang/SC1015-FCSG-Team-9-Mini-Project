# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
heart= pd.read_csv('selected_heartdata.csv')

# %%
heart.head()
# Out:
#    HeartDisease  GenHealth  DiffWalking  Stroke  PhysicalHealth
# 0             0          3            0       0             3.0
# 1             0          3            0       1             0.0
# 2             0          2            0       0             0.0
# 3             0          1            0       0             0.0
# 4             0          2            1       0             0.0

# %%
PhysicalHealth = pd.DataFrame(heart['PhysicalHealth'])
GenHealth = pd.DataFrame(heart['GenHealth'])
DiffWalking = pd.DataFrame(heart['DiffWalking'])
Stroke = pd.DataFrame(heart['Stroke'])
HeartDisease = pd.DataFrame(heart['HeartDisease'])

# %%
sb.jointplot(data = heart, x = "PhysicalHealth", y = "HeartDisease", height = 12, ax= axes[0,0])
sb.jointplot(data = heart, x = "GenHealth", y = "HeartDisease", height = 12)
sb.jointplot(data = heart, x = "DiffWalking", y = "HeartDisease", height = 12)
sb.jointplot(data = heart, x = "Stroke", y = "HeartDisease", height = 12)
# Out:
# /var/folders/6m/60w3bmtx2dv_17bhhk0rrdp80000gn/T/ipykernel_47958/3428332842.py:1: UserWarning: Ignoring `ax`; jointplot is a figure-level function.
#   sb.jointplot(data = heart, x = "PhysicalHealth", y = "HeartDisease", height = 12, ax= axes[0,0])

# %%
sb.pairplot(data=heart)
plt.show()
# Out:
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
heart.corr()
# Out:
#                 HeartDisease  GenHealth  DiffWalking    Stroke  PhysicalHealth
# HeartDisease        1.000000  -0.181333     0.141762  0.159871        0.033726
# GenHealth          -0.181333   1.000000    -0.254342 -0.112046       -0.161789
# DiffWalking         0.141762  -0.254342     1.000000  0.128650        0.088487
# Stroke              0.159871  -0.112046     0.128650  1.000000        0.027137
# PhysicalHealth      0.033726  -0.161789     0.088487  0.027137        1.000000

# %%
sb.heatmap(data = heart) 
plt.show()
