# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
heart= pd.read_csv('selected_heartdata.csv')

# %%
heart.head()
# Out:
#    HeartDisease  GenHealth  AgeCategory  DiffWalking  PhysicalHealth
# 0             1          1            1            1             6.0
# 1             1          0            1            1            10.0
# 2             1          2            0            1             0.0
# 3             1          1            1            1             6.0
# 4             1          0            2            0             3.0

# %%
# GENHEALTH COUNT
print("Number of Categories :", len(heart["GenHealth"].unique()))
print(heart["GenHealth"].value_counts())
sb.catplot(y = "GenHealth", data = heart, kind = "count", height = 8)

# DIFFWALKING COUNT
print("Number of Categories :", len(heart["DiffWalking"].unique()))
# Data of each DiffWalking
print(heart["DiffWalking"].value_counts())
sb.catplot(y = "DiffWalking", data = heart, kind = "count", height = 8)

# STROKE COUNT
print("Number of Categories :", len(heart["AgeCategory"].unique()))
print(heart["AgeCategory"].value_counts())
sb.catplot(y = "AgeCategory", data = heart, kind = "count", height = 8)

# PHYSICAL HEALTH COUNT
print("Number of Categories :", len(heart["PhysicalHealth"].unique()))
print(heart["PhysicalHealth"].value_counts())
sb.catplot(y = "PhysicalHealth", data = heart, kind = "count", height = 8)
# Out:
# Number of Categories : 5
# GenHealth
# 2    15736
# 3    14883
# 4     7543
# 1     6027
# 0      839
# Name: count, dtype: int64
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Number of Categories : 2
# DiffWalking
# 0    37993
# 1     7035
# Name: count, dtype: int64
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Number of Categories : 13
# AgeCategory
# 2     5898
# 0     5774
# 3     5601
# 4     4746
# 1     4481
# 5     3681
# 6     2982
# 7     2279
# 8     2144
# 9     2005
# 12    1989
# 10    1769
# 11    1679
# Name: count, dtype: int64
# ...

# %%
print(heart.dtypes)
PhysicalHealth = pd.DataFrame(heart['PhysicalHealth'])
# Out:
# HeartDisease        int64
# GenHealth           int64
# AgeCategory         int64
# DiffWalking         int64
# PhysicalHealth    float64
# dtype: object

# %%
PhysicalHealth = pd.DataFrame(heart['PhysicalHealth'])
GenHealth = pd.DataFrame(heart['GenHealth'])
DiffWalking = pd.DataFrame(heart['DiffWalking'])
AgeCategory  = pd.DataFrame(heart['AgeCategory'])
HeartDisease = pd.DataFrame(heart['HeartDisease'])

# %%
f = plt.figure(figsize=(16, 8))
sb.boxplot(data = PhysicalHealth, orient = "h")



f = plt.figure(figsize=(16, 8))
sb.boxplot(data = GenHealth, orient = "h")



f = plt.figure(figsize=(16, 8))
sb.boxplot(data = DiffWalking, orient = "h")


f = plt.figure(figsize=(16, 8))
sb.boxplot(data = AgeCategory, orient = "h")
# Out:
# <Axes: >

# %%
# HeartDisease over GenHealth
sb.catplot(y = 'HeartDisease', data = heart, col = 'GenHealth', kind = 'count', col_wrap = 2, height = 8)
# Out:
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# HeartDisease over PhysicalHealth
sb.catplot(y = 'HeartDisease', data = heart, col = 'PhysicalHealth', kind = 'count', col_wrap = 2, height = 8)
# Out:
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# HeartDisease over DiffWalking
sb.catplot(y = 'HeartDisease', data = heart, col = 'DiffWalking', kind = 'count', col_wrap = 2, height = 8)
# Out:
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# HeartDisease over AgeCategory
sb.catplot(y = 'HeartDisease', data = heart, col = 'AgeCategory', kind = 'count', col_wrap = 2, height = 8)
# Out:
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
numeric_data = pd.DataFrame(heart)


numeric_data.describe()
# Out:
#        HeartDisease     GenHealth   AgeCategory   DiffWalking  PhysicalHealth
# count  45028.000000  45028.000000  45028.000000  45028.000000    45028.000000
# mean       0.448055      2.494448      4.431420      0.156236        1.044395
# std        0.497300      0.982102      3.486472      0.363083        2.364334
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%        0.000000      2.000000      2.000000      0.000000        0.000000
# 50%        0.000000      2.000000      4.000000      0.000000        0.000000
# 75%        1.000000      3.000000      7.000000      0.000000        0.000000
# max        1.000000      4.000000     12.000000      1.000000       12.000000

# %%
f = plt.figure(figsize=(16, 8))
sb.violinplot(data = PhysicalHealth, orient = "h")


f = plt.figure(figsize=(16, 8))
sb.violinplot(data = GenHealth, orient = "h")


f = plt.figure(figsize=(16, 8))
sb.violinplot(data = DiffWalking, orient = "h")


f = plt.figure(figsize=(16, 8))
sb.violinplot(data = AgeCategory, orient = "h")
# Out:
# <Axes: >

# %%
f = plt.figure(figsize=(16, 8))
sb.histplot(data = PhysicalHealth)



f = plt.figure(figsize=(16, 8))
sb.histplot(data = GenHealth)



f = plt.figure(figsize=(16, 8))
sb.histplot(data = DiffWalking)



f = plt.figure(figsize=(16, 8))
sb.histplot(data = AgeCategory)
# Out:
# <Axes: ylabel='Count'>

# %%
sb.catplot(x="PhysicalHealth", y="HeartDisease", data=heart)
plt.show()



sb.catplot(x="GenHealth", y="HeartDisease", data=heart)
plt.show()


sb.catplot(x="AgeCategory", y="HeartDisease", data=heart)
plt.show()


sb.catplot(x="DiffWalking", y="HeartDisease", data=heart)
plt.show()
# Out:
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.jointplot(data = heart, x = "PhysicalHealth", y = "HeartDisease", height = 12)
sb.jointplot(data = heart, x = "GenHealth", y = "HeartDisease", height = 12)
sb.jointplot(data = heart, x = "DiffWalking", y = "HeartDisease", height = 12)
sb.jointplot(data = heart, x = "AgeCategory", y = "HeartDisease", height = 12)

# %%
sb.pairplot(data=heart)
plt.show()
# Out:
# /Users/dee/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
