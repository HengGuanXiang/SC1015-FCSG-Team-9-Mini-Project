# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
heart= pd.read_csv('etadata.csv')

# %%
heart.head()
# Out:
#    HeartDisease  GenHealth Stroke DiffWalking  AgeCategory  PhysicalHealth
# 0             0  Very good     No          No        55-59             3.0
# 1             0  Very good    Yes          No  80 or older             0.0
# 2             0       Fair     No          No        65-69            20.0
# 3             0       Good     No          No        75-79             0.0
# 4             0  Very good     No         Yes        40-44            28.0

# %%
# Function to add count labels to the bars
def add_count_labels(ax, data):
    for p in ax.patches:
        ax.annotate(f'\n{int(p.get_width())}', (p.get_width(), p.get_y()), ha='left', va='center', color='black', fontsize=10)


# GENHEALTH COUNT
print("Number of Categories :", len(heart["GenHealth"].unique()))
print(heart["GenHealth"].value_counts())
plt.figure(figsize=(10, 6))
ax = sb.countplot(y="GenHealth", data=heart, order=heart["GenHealth"].value_counts().index)
add_count_labels(ax, heart["GenHealth"].value_counts())
plt.title('Count of GenHealth')
plt.xlabel('Count')
plt.ylabel('GenHealth')
plt.show()

# DIFFWALKING COUNT
print("Number of Categories :", len(heart["DiffWalking"].unique()))
print(heart["DiffWalking"].value_counts())
plt.figure(figsize=(10, 6))
ax = sb.countplot(y="DiffWalking", data=heart, order=heart["DiffWalking"].value_counts().index)
add_count_labels(ax, heart["DiffWalking"].value_counts())
plt.title('Count of DiffWalking')
plt.xlabel('Count')
plt.ylabel('DiffWalking')
plt.show()

# AGECATEGORY COUNT
print("Number of Categories :", len(heart["AgeCategory"].unique()))
print(heart["AgeCategory"].value_counts())
plt.figure(figsize=(10, 6))
ax = sb.countplot(y="AgeCategory", data=heart, order=heart["AgeCategory"].value_counts().index)
add_count_labels(ax, heart["AgeCategory"].value_counts())
plt.title('Count of AgeCategory')
plt.xlabel('Count')
plt.ylabel('AgeCategory')
plt.show()

# PHYSICAL HEALTH COUNT
print("Number of Categories :", len(heart["PhysicalHealth"].unique()))
print(heart["PhysicalHealth"].value_counts())
plt.figure(figsize=(10, 6))
ax = sb.countplot(y="PhysicalHealth", data=heart, order=heart["PhysicalHealth"].value_counts().index)
add_count_labels(ax, heart["PhysicalHealth"].value_counts())
plt.title('Count of PhysicalHealth')
plt.xlabel('Count')
plt.ylabel('PhysicalHealth')
plt.show()

# STROKE COUNT
print("Number of Categories :", len(heart["Stroke"].unique()))
print(heart["Stroke"].value_counts())
plt.figure(figsize=(10, 6))
ax = sb.countplot(y="Stroke", data=heart, order=heart["Stroke"].value_counts().index)
add_count_labels(ax, heart["Stroke"].value_counts())
plt.title('Count of Stroke')
plt.xlabel('Count')
plt.ylabel('Stroke')
plt.show()
# Out:
# Number of Categories : 5
# Very good    113858
# Good          93129
# Excellent     66842
# Fair          34677
# Poor          11289
# Name: GenHealth, dtype: int64
# Number of Categories : 2
# No     275385
# Yes     44410
# Name: DiffWalking, dtype: int64
# Number of Categories : 13
# 65-69          34151
# 60-64          33686
# 70-74          31065
# 55-59          29757
# 50-54          25382
# 80 or older    24153
# 45-49          21791
# 75-79          21482
# 18-24          21064
# 40-44          21006
# 35-39          20550
# 30-34          18753
# 25-29          16955
# Name: AgeCategory, dtype: int64
# Number of Categories : 31
# 0.0     226589
# 30.0     19509
# 2.0      14880
# 1.0      10489
# 3.0       8617
# 5.0       7606
# 10.0      5453
# 15.0      5012
# 7.0       4629
# 4.0       4468
# 20.0      3216
# 14.0      2893
# 6.0       1270
# 25.0      1164
# 8.0        924
# 21.0       626
# 12.0       605
# 28.0       446
# 29.0       204
# 9.0        180
# ...

# %%
print(heart.dtypes)
PhysicalHealth = pd.DataFrame(heart['PhysicalHealth'])
# Out:
# HeartDisease        int64
# GenHealth          object
# Stroke             object
# DiffWalking        object
# AgeCategory        object
# PhysicalHealth    float64
# dtype: object

# %%
heart2= pd.read_csv('selected_heartdata.csv')

# %%
PhysicalHealth = pd.DataFrame(heart2['PhysicalHealth'])
GenHealth = pd.DataFrame(heart2['GenHealth'])
DiffWalking = pd.DataFrame(heart2['DiffWalking'])
AgeCategory  = pd.DataFrame(heart2['AgeCategory'])
HeartDisease = pd.DataFrame(heart2['HeartDisease'])

# %%
f = plt.figure(figsize=(16, 8))
sb.boxplot(data = PhysicalHealth, orient = "h")



f = plt.figure(figsize=(16, 8))
sb.boxplot(data = GenHealth, orient = "h")


f = plt.figure(figsize=(16, 8))
sb.boxplot(data = AgeCategory, orient = "h")
# Out:
# <AxesSubplot:>

# %%
PhysicalHealth = pd.DataFrame(heart['PhysicalHealth'])
GenHealth = pd.DataFrame(heart['GenHealth'])
DiffWalking = pd.DataFrame(heart['DiffWalking'])
AgeCategory  = pd.DataFrame(heart['AgeCategory'])
Stroke  = pd.DataFrame(heart['Stroke'])
HeartDisease = pd.DataFrame(heart['HeartDisease'])

# %%
import seaborn as sns

sns.catplot(x='GenHealth', hue='HeartDisease', kind='count', data=heart, height=6, aspect=2)

# Add count numbers above the bars
ax = plt.gca()
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Set labels and title
plt.xlabel('General Health')
plt.ylabel('Frequency')
plt.title('Distribution of Heart Disease by General Health')

# Show the plot
plt.show()

# %%
sns.catplot(x='PhysicalHealth', hue='HeartDisease', kind='count', data=heart, height=8, aspect=2)
plt.xlabel('PhysicalHealth')
plt.ylabel('Frequency')
plt.title('Distribution of Heart Disease by PhysicalHealth')
plt.show()

# %%
sns.catplot(x='DiffWalking', hue='HeartDisease', kind='count', data=heart, height=6, aspect=2)

# Add count numbers above the bars
ax = plt.gca()
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Set labels and title
plt.xlabel('DiffWalking')
plt.ylabel('Frequency')
plt.title('Distribution of Heart Disease by DiffWalking')

# Show the plot
plt.show()

# %%
sns.catplot(x='AgeCategory', hue='HeartDisease', kind='count', data=heart, height=6, aspect=2)

# Add count numbers above the bars
ax = plt.gca()
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Set labels and title
plt.xlabel('AgeCategory')
plt.ylabel('Frequency')
plt.title('Distribution of Heart Disease by AgeCategory')

# Show the plot
plt.show()

# %%
sns.catplot(x='Stroke', hue='HeartDisease', kind='count', data=heart, height=6, aspect=2)

# Add count numbers above the bars
ax = plt.gca()
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# Set labels and title
plt.xlabel('Stroke')
plt.ylabel('Frequency')
plt.title('Distribution of Heart Disease by Stroke')

# Show the plot
plt.show()

# %%
numeric_data = pd.DataFrame(heart)


numeric_data.describe()
# Out:
#         HeartDisease  PhysicalHealth
# count  319795.000000    319795.00000
# mean        0.085595         3.37171
# std         0.279766         7.95085
# min         0.000000         0.00000
# 25%         0.000000         0.00000
# 50%         0.000000         0.00000
# 75%         0.000000         2.00000
# max         1.000000        30.00000

# %%
PhysicalHealth = pd.DataFrame(heart2['PhysicalHealth'])
GenHealth = pd.DataFrame(heart2['GenHealth'])
DiffWalking = pd.DataFrame(heart2['DiffWalking'])
AgeCategory  = pd.DataFrame(heart2['AgeCategory'])
Stroke = pd.DataFrame(heart2['Stroke'])
HeartDisease = pd.DataFrame(heart2['HeartDisease'])

# %%
f = plt.figure(figsize=(16, 8))
sb.violinplot(data = PhysicalHealth, orient = "h")


f = plt.figure(figsize=(16, 8))
sb.violinplot(data = GenHealth, orient = "h")


f = plt.figure(figsize=(16, 8))
sb.violinplot(data = DiffWalking, orient = "h")


f = plt.figure(figsize=(16, 8))
sb.violinplot(data = AgeCategory, orient = "h")


f = plt.figure(figsize=(16, 8))
sb.violinplot(data = Stroke, orient = "h")
# Out:
# <AxesSubplot:>

# %%
sb.jointplot(data = heart, x = "PhysicalHealth", y = "HeartDisease", height = 12)
sb.jointplot(data = heart, x = "GenHealth", y = "HeartDisease", height = 12)
sb.jointplot(data = heart, x = "DiffWalking", y = "HeartDisease", height = 12)
sb.jointplot(data = heart, x = "AgeCategory", y = "HeartDisease", height = 12)
